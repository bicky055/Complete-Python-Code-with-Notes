# %% [markdown]
# ### Real-World Examples Using Lists in Python
# Lists are one of the most commonly used data structures in Python, thanks to their versatility and ease of use. Here are several practical examples that illustrate their use in real-world scenarios
#
# ##### Example 1. Manage A To Do List
# Create a To Do List To Keep Track OF Tasks

# %%
to_do_list = ["Buy Groceries", "Clean the House", "Pay Bills"]

## adding to task
to_do_list.append("Schedule Meeting")
to_do_list.append("Go to Run")

## Removing a task
to_do_list.remove("Clean the House")

## checking if a task is in the list
if "pay Bills" in to_do_list:
    print("Don't forget to pay the bills!")

print(" TO DO List Remaining")
for task in to_do_list:
    print(f" - {task}")
# Out:
#  TO DO List Remaining
#  - Buy Groceries
#  - Pay Bills
#  - Schedule Meeting
#  - Go to Run

# %% [markdown]
# ##### Example 2: Organizing Student Grades
# Create a list to store and calculate average grades for students

# %%
# organizing Student Grades
grades = [85, 90, 78, 92, 88]

# adding a new grade
grades.append(95)

# calculating average grade
average_grade = sum(grades) / len(grades)
print(f"Average Grade: {average_grade}")

# Finding the highest and lowest grades
highest_grade = max(grades)
lowest_grade = min(grades)
print(f"Highest Grade: {highest_grade}")
print(f"Lowest Grade: {lowest_grade}")
# Out:
# Average Grade: 88.0
# Highest Grade: 95
# Lowest Grade: 78

# %% [markdown]
# ##### Example 3: Managing An Inventory
# Use a list to manage inventory items in a store

# %%
# Managing an Inventory
iventory = ["Apples", "Bananas", "Oranges"]

# Adding new items to the inventory
iventory.append("Grapes")

# Removing an item from the inventory
iventory.remove("Bananas")

# Checking if an item is in stock
item = "Oranges"
if item in iventory:
    print(f"{item} is in stock.")
else:
    print(f"{item} is out of stock.")


#printing the current inventory
print("Current Inventory:")
for fruit in iventory:
    print(f" - {fruit}")
# Out:
# Oranges is in stock.
# Current Inventory:
#  - Apples
#  - Oranges
#  - Grapes

# %% [markdown]
# ##### Example 4:Collecting User Feedback
# Use a list to collect and analyze user feedback.

# %%
# collecting User Feedback
feedback = ["Great service!", "Could improve the website.", "Loved the product selection."]

# Adding new feedback
feedback.append("Customer support was very helpful.")

# counting total feedback entries
positive_feedback = sum(1 for comment in feedback if "great" in comment.lower() or "loved" in comment.lower())
print(f"Total Feedback Entries: {len(feedback)}")
print(f"Positive Feedback Entries: {positive_feedback}")

# printing all feedback comments
print("User Feedback:")
for comment in feedback:
    print(f" - {comment}")
# Out:
# Total Feedback Entries: 4
# Positive Feedback Entries: 2
# User Feedback:
#  - Great service!
#  - Could improve the website.
#  - Loved the product selection.
#  - Customer support was very helpful.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
