# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
x = int(input("enter the number: "))
print(x)

name = str(input("Enter the name: "))
print(name)
# Out:
# 5
# bicky

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
int_num = int(input("Enter an integer: "))
if int_num == 0:
    print("The number is zero.")
if int_num % 2 == 0:
    print("The number is even.")
else:
    print("The number is odd.")
# Out:
# The number is even.

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
x = 10; y = 12; z = 5;
if x > y and x > z:
    print(x)
elif y > x and y > z:
    print(y)
else:   
    print(z)
# Out:
# 12

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
factorial = 1
num = int(input("Enter a number to calculate its factorial: "))
if num < 0:
    print("Factorial is not defined for negative numbers")  
elif num == 0:
    print("Factorial of 0 is 1")

for i in range(1, num+1):
    factorial *= i
print(f"The factorial of {num} is {factorial}")
# Out:
# The factorial of 5 is 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
x = 10 
y = 10.57
name = "Bicky Jha"
a = True

print(f"Integer: {x}, Float: {y}, String: {name}, Boolean: {a}")
print(type(x))
print(type(y))
print(type(name))
print(type(a))
# Out:
# Integer: 10, Float: 10.57, String: Bicky Jha, Boolean: True
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
a = 10
b = 20
print(f"Before swapping: a = {a}, b = {b}")
a, b = b, a
print(f"After swapping: a ={a}, b = {b}")
# Out:
# Before swapping: a = 10, b = 20
# After swapping: a =20, b = 10

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
celsius = float(input("Enter temperature in Celsius:"))
fahrenheit = (celsius * 9/5) + 32
print(f"{celsius} Celsius is equal to {fahrenheit} Fahrenheit")
# Out:
# 25.0 Celsius is equal to 77.0 Fahrenheit

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
str1 = "Bicky"
str2 = "Jha"

concatenate_str = str1 + " " + str2
print(f"Concatenate String {concatenate_str}")
# Out:
# Concatenate String Bicky Jha

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
var = 10.5
if isinstance(var, float):
    print(f"{var} is a Float")
else:
    print(f"{var} is not a Float")
# Out:
# 10.5 is a Float

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
a = 20
b = 10
addition = a+b
sub = a - b
multiplication = a*b
division = a/b
print(f"addition of {a} and {b} is {addition}")
print(f"subtraction of {a} and {b} is {sub}")
print(f"Multiplication of {a} and {b} is {multiplication}")
print(f"Division of {a} and {b} is {division}")
# Out:
# addition of 20 and 10 is 30
# subtraction of 20 and 10 is 10
# Multiplication of 20 and 10 is 200
# Division of 20 and 10 is 2.0

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
a = 3
b = 5
print(f"{a} == {b} : {a == b} ")
print(f"{a} != {b} : {a != b}")
print(f"{a} > {b} : {a > b}")
print(f"{a} < {b} : {a < b}")
print(f"{a} >= {b} : {a >= b}") 
print(f"{a} <= {b} : {a <= b}")
# Out:
# 3 == 5 : False
# 3 != 5 : True
# 3 > 5 : False
# 3 < 5 : True
# 3 >= 5 : False
# 3 <= 5 : True

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
a = True
b = False
print(f" a && b : {a and b }")
print(f" a || b : {a or b }")
print(f" !a : {not a}")
# Out:
#  a && b : False
#  a || b : True
#  !a : False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
num = int(input("Enter a number: "))
num = num ** 2
print(f"The square of the number is: {num}")
# Out:
# The square of the number is: 64

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
num = int(input("Enter a number:"))
if num % 2 == 0:
    print(f"{num} is an even number.")
else:
    print(f"{num} is an odd number.")
# Out:
# 8 is an even number.

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
num = int(input("Enter a number: "))
sum = (num * (num + 1) ) /2
print(f"The sum of the first {num} natural numbers is: {sum}")
# Out:
# The sum of the first 10 natural numbers is: 55.0

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
n = int(input("Enter a number: "))
# check leap year
if (n % 4 == 0 and n % 100 != 0) or (n % 400 == 0):
    print(f"{n} is a leap year.")
else:
    print(f"{n} is not a leap year.")
# Out:
# 2012 is a leap year.

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
str = "Bicky jha"
reversed_str = str[::-1]
print(f"The reversed string is: {reversed_str}")
# Out:
# The reversed string is: ahj ykciB

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
str = "aabcabaa"
reversed_str = str[::-1]
if str == reversed_str:
    print(f"{str } is a palindrome")
else:  
    print(f"{str } is not a palindrome")
# Out:
# aabcabaa is not a palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
# sort a list 
my_list = [int(i) for i in input("Enter numbers separated by space:").split()]
my_list.sort()
print(f"The sorted list is: {my_list}")
# Out:
# The sorted list is: [2, 4, 5, 6, 7]
